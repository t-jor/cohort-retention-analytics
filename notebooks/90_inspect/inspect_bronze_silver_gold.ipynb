# %%
spark.sql("USE CATALOG etl_project")
spark.sql("USE SCHEMA bigquery_db_cohort_db")

tables = [
    "bronze_ecom_orders",
    "silver_customer_facts",
    "silver_order_facts",
    "gold_cohort_retention",
    "gold_cohort_sizes",
    "gold_repeat_purchases",
    "gold_order_distribution",
    "vw_cohort_analysis"
]

for t in tables:
    print(f"Preview: {t}")
    display(spark.table(t).limit(10))
