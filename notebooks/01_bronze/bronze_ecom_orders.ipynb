# %%
# %sql
-- Use project catalog and schema
USE CATALOG etl_project;
USE SCHEMA bigquery_db_cohort_db;

-- Build the Bronze ecom orders table
CREATE OR REPLACE TABLE bronze_ecom_orders AS
SELECT
  order_id,
  order_date,
  sales,
  customer_id
FROM ecom_orders;
